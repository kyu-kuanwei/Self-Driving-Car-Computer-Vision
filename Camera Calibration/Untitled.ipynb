# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

#Read in an image
img = mpimg.imread('calibration_test.png')
plt.imshow(img)

# %%
# Arrays to object points and image points from all the images
objpoints = [] # 3D points in real world space
imgpoints = [] # 2D point in image space

# %%
#comvert to the grayscale image
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap='gray')

# %%
ret, corners = cv2.findChessboardCorners(gray, (8,6), None)
img = cv2.drawChessboardCorners(img, (8,6), corners, ret)
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
dst = cv2.undistort(img, mtx, dist, None, mtx)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-10f98c96ec9e> in <module>
# ----> 1 ret, corners = cv2.findChessboardCorners(gray, (8,6), None)
#       2 img = cv2.drawChessboardCorners(img, (8,6), corners, ret)
#       3 ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)
#       4 dst = cv2.undistort(img, mtx, dist, None, mtx)
#
# error: OpenCV(4.1.2) /Users/travis/build/skvark/opencv-python/opencv/modules/calib3d/src/calibinit.cpp:503: error: (-2:Unspecified error) in function 'bool cv::findChessboardCorners(InputArray, Size, OutputArray, int)'
# > Only 8-bit grayscale or color images are supported:
# >     'depth == CV_8U && (cn == 1 || cn == 3 || cn == 4)'
# > where
# >     'type' is 5 (CV_32FC1)
